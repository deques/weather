# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('weather_data.csv')
df = df.iloc[:, 1:]
df["date"] = pd.to_datetime(df["date"])
df
# Out:
#                          date  temperature_2m_max  temperature_2m_min  \
# 0   2024-01-01 00:00:00+00:00            9.886500              5.9365
# 1   2024-01-02 00:00:00+00:00           12.086500              9.8365
# 2   2024-01-03 00:00:00+00:00           12.136500              8.5865
# 3   2024-01-04 00:00:00+00:00           10.736501              6.5865
# 4   2024-01-05 00:00:00+00:00            9.186501              3.1865
# ..                        ...                 ...                 ...
# 361 2024-12-27 00:00:00+00:00            5.436500             -1.1135
# 362 2024-12-28 00:00:00+00:00            1.686500             -0.5635
# 363 2024-12-29 00:00:00+00:00            4.786500              1.3365
# 364 2024-12-30 00:00:00+00:00            4.236500              2.5365
# 365 2024-12-31 00:00:00+00:00            5.736500              1.8365
#
#      weather_code  precipitation_sum  temperature_2m_mean
# 0            55.0                3.6             8.030250
# ...

# %%
# Plot the data
plt.figure(figsize=(10, 5))  # Set figure size
plt.plot(df["date"], df["temperature_2m_max"], label="Temperatur (°C)", color="blue", marker="o")

# Format the X-axis
plt.xlabel("Datum")
plt.ylabel("Temperatur (°C)")
plt.title("Temperatur i Norrköping under 2024")
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend()
plt.grid()

plt.show()

# %%
# Create figure and axis
fig, ax1 = plt.subplots(figsize=(10, 5))

# Plot Temperature on Primary Y-Axis
ax1.plot(df["date"], df["temperature_2m_max"], label="Max Temperatur (°C)", color="red", marker="o")
ax1.plot(df["date"], df["temperature_2m_min"], label="Min Temperatur (°C)", color="blue", marker="o")
ax1.set_xlabel("Datum")
ax1.set_ylabel("Temperatur (°C)")
ax1.tick_params(axis="y", labelcolor="red")

# Create a second Y-axis for precipitation
ax2 = ax1.twinx()
ax2.bar(df["date"], df["precipitation_sum"], label="Nederbörd (mm)", color="black", alpha=0.5)
ax2.set_ylabel("Nederbörd (mm)")
ax2.tick_params(axis="y", labelcolor="blue")

# Formatting
plt.title("Temperatur & nederbörd i Norrköping")
fig.autofmt_xdate()  # Rotate x-axis labels
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.grid()
